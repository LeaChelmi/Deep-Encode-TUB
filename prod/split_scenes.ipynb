# %%
import os
import pandas as pd
import subprocess

# %%
data_set_path='/Volumes/T7/deep_encode_dataset/DATASET_DEEP_ENCODE_2/pipeline_dataset'

# %%
metadata = pd.read_csv(os.path.join(data_set_path, 'metadata.csv'))

# %%
videos = os.listdir(data_set_path)

for video in videos:

    video_path = os.path.join(data_set_path, video)

    if not os.path.isdir(video_path):
        continue

    raw_video = os.listdir(video_path)[0]
    raw_video_path = os.path.join(video_path, raw_video)

    # get meta data
    res=metadata.loc[metadata.VideoName == f'{video}','Resolution'].item()
    fps=metadata.loc[metadata.VideoName == f'{video}','FPS'].item()
    pix_fmt=metadata.loc[metadata.VideoName == f'{video}','PIX_FMT'].item()

    # split command
    split_cmd = f'scenedetect -i {raw_video_path} -o {video_path}/scenes detect-content split-video -a "-f rawvideo -vcodec rawvideo -s {res} -r {fps} -pix_fmt {pix_fmt} -c:v libx264 -preset ultrafast -qp 0"'
    split_result = subprocess.run(split_cmd, capture_output=True, text=True, shell=True)
    print(split_result)
# Out:
# CompletedProcess(args='scenedetect -i /Volumes/T7/deep_encode_dataset/DATASET_DEEP_ENCODE_2/pipeline_dataset/CSGO/CSGO.y4m -o /Volumes/T7/deep_encode_dataset/DATASET_DEEP_ENCODE_2/pipeline_dataset/CSGO/scenes detect-content split-video -a "-f rawvideo -vcodec rawvideo -s 1920x1080 -r 60 -pix_fmt yuv420p -c:v libx264 -preset ultrafast -qp 0"', returncode=0, stdout='[PySceneDetect] PySceneDetect v0.6.1\n[PySceneDetect] Output directory set:\n  /Volumes/T7/deep_encode_dataset/DATASET_DEEP_ENCODE_2/pipeline_dataset/CSGO/scenes\n[PySceneDetect] ffmpeg arguments: -f rawvideo -vcodec rawvideo -s 1920x1080 -r 60 -pix_fmt yuv420p -c:v libx264 -preset ultrafast -qp 0\n[PySceneDetect] Downscale factor set to 7, effective resolution: 274 x 154\n[PySceneDetect] Detecting scenes...\n[PySceneDetect] Processed 3602 frames in 13.3 seconds (average 270.20 FPS).\n[PySceneDetect] Detected 8 scenes, average shot length 7.5 seconds.\n[PySceneDetect] Comma-separated timecode list:\n  00:00:32.617,00:00:35.450,00:00:36.867,00:00:39.917,00:00:43.333,00:00:56.667,00:00:57.467\n[PySceneDetect] Splitting input video using ffmpeg, output path template:\n  /Volumes/T7/deep_encode_dataset/DATASET_DEEP_ENCODE_2/pipeline_dataset/CSGO/scenes/$VIDEO_NAME-Scene-$SCENE_NUMBER.mp4\n[PySceneDetect] Output from ffmpeg for Scene 1 shown above, splitting remaining scenes...\n[PySceneDetect] Average processing speed 158.65 frames/sec.\n[PySceneDetect] Video splitting completed, individual scenes written to disk.\n', stderr="\nDetected: 0 | Progress:   0%|          | 0/3602 [00:00<?, ?frames/s]\n                                                                    \n\nDetected: 0 | Progress:   0%|          | 0/3602 [00:00<?, ?frames/s]\nDetected: 0 | Progress:   1%|          | 25/3602 [00:00<00:14, 239.83frames/s]\nDetected: 0 | Progress:   1%|▏         | 53/3602 [00:00<00:13, 258.57frames/s]\nDetected: 0 | Progress:   2%|▏         | 82/3602 [00:00<00:13, 269.58frames/s]\nDetected: 0 | Progress:   3%|▎         | 112/3602 [00:00<00:12, 278.28frames/s]\nDetected: 0 | Progress:   4%|▍         | 141/3602 [00:00<00:12, 282.36frames/s]\nDetected: 0 | Progress:   5%|▍         | 170/3602 [00:00<00:12, 267.86frames/s]\nDetected: 0 | Progress:   5%|▌         | 197/3602 [00:00<00:12, 264.07frames/s]\nDetected: 0 | Progress:   6%|▌         | 224/3602 [00:00<00:13, 255.67frames/s]\nDetected: 0 | Progress:   7%|▋         | 250/3602 [00:00<00:13, 251.47frames/s]\nDetected: 0 | Progress:   8%|▊         | 277/3602 [00:01<00:13, 254.14frames/s]\nDetected: 0 | Progress:   8%|▊         | 303/3602 [00:01<00:13, 242.75frames/s]\nDetected: 0 | Progress:   9%|▉         | 329/3602 [00:01<00:13, 246.04frames/s]\nDetected: 0 | Progress:  10%|▉         | 358/3602 [00:01<00:12, 257.87frames/s]\nDetected: 0 | Progress:  11%|█         | 388/3602 [00:01<00:11, 268.98frames/s]\nDetected: 0 | Progress:  12%|█▏        | 418/3602 [00:01<00:11, 276.48frames/s]\nDetected: 0 | Progress:  12%|█▏        | 448/3602 [00:01<00:11, 283.18frames/s]\nDetected: 0 | Progress:  13%|█▎        | 479/3602 [00:01<00:10, 289.15frames/s]\nDetected: 0 | Progress:  14%|█▍        | 509/3602 [00:01<00:10, 292.06frames/s]\nDetected: 0 | Progress:  15%|█▍        | 540/3602 [00:01<00:10, 295.78frames/s]\nDetected: 0 | Progress:  16%|█▌        | 571/3602 [00:02<00:10, 297.87frames/s]\nDetected: 0 | Progress:  17%|█▋        | 602/3602 [00:02<00:10, 298.81frames/s]\nDetected: 0 | Progress:  18%|█▊        | 633/3602 [00:02<00:09, 301.09frames/s]\nDetected: 0 | Progress:  18%|█▊        | 664/3602 [00:02<00:09, 298.08frames/s]\nDetected: 0 | Progress:  19%|█▉        | 694/3602 [00:02<00:10, 284.61frames/s]\nDetected: 0 | Progress:  20%|██        | 723/3602 [00:02<00:10, 275.04frames/s]\nDetected: 0 | Progress:  21%|██        | 751/3602 [00:02<00:10, 275.38frames/s]\nDetected: 0 | Progress:  22%|██▏       | 780/3602 [00:02<00:10, 278.12frames/s]\nDetected: 0 | Progress:  22%|██▏       | 809/3602 [00:02<00:09, 279.99frames/s]\nDetected: 0 |  ...
# CompletedProcess(args='scenedetect -i /Volumes/T7/deep_encode_dataset/DATASET_DEEP_ENCODE_2/pipeline_dataset/720p50_mobcal_ter/720p50_mobcal_ter.y4m -o /Volumes/T7/deep_encode_dataset/DATASET_DEEP_ENCODE_2/pipeline_dataset/720p50_mobcal_ter/scenes detect-content split-video -a "-f rawvideo -vcodec rawvideo -s 1280x720 -r 50 -pix_fmt yuv420p -c:v libx264 -preset ultrafast -qp 0"', returncode=0, stdout='[PySceneDetect] PySceneDetect v0.6.1\n[PySceneDetect] Output directory set:\n  /Volumes/T7/deep_encode_dataset/DATASET_DEEP_ENCODE_2/pipeline_dataset/720p50_mobcal_ter/scenes\n[PySceneDetect] ffmpeg arguments: -f rawvideo -vcodec rawvideo -s 1280x720 -r 50 -pix_fmt yuv420p -c:v libx264 -preset ultrafast -qp 0\n[PySceneDetect] Downscale factor set to 5, effective resolution: 256 x 144\n[PySceneDetect] Detecting scenes...\n[PySceneDetect] Processed 504 frames in 1.0 seconds (average 483.45 FPS).\n[PySceneDetect] Detected 2 scenes, average shot length 5.0 seconds.\n[PySceneDetect] Comma-separated timecode list:\n  00:00:10.040\n[PySceneDetect] Splitting input video using ffmpeg, output path template:\n  /Volumes/T7/deep_encode_dataset/DATASET_DEEP_ENCODE_2/pipeline_dataset/720p50_mobcal_ter/scenes/$VIDEO_NAME-Scene-$SCENE_NUMBER.mp4\n[PySceneDetect] Output from ffmpeg for Scene 1 shown above, splitting remaining scenes...\n[PySceneDetect] Average processing speed 326.66 frames/sec.\n[PySceneDetect] Video splitting completed, individual scenes written to disk.\n', stderr="\nDetected: 0 | Progress:   0%|          | 0/504 [00:00<?, ?frames/s]\n                                                                   \n\nDetected: 0 | Progress:   0%|          | 0/504 [00:00<?, ?frames/s]\nDetected: 0 | Progress:  10%|▉         | 49/504 [00:00<00:00, 482.72frames/s]\nDetected: 0 | Progress:  20%|█▉        | 100/504 [00:00<00:00, 493.78frames/s]\nDetected: 0 | Progress:  30%|██▉       | 150/504 [00:00<00:00, 494.43frames/s]\nDetected: 0 | Progress:  40%|███▉      | 200/504 [00:00<00:00, 496.23frames/s]\nDetected: 0 | Progress:  50%|████▉     | 251/504 [00:00<00:00, 499.77frames/s]\nDetected: 0 | Progress:  60%|█████▉    | 302/504 [00:00<00:00, 502.24frames/s]\nDetected: 0 | Progress:  70%|███████   | 353/504 [00:00<00:00, 500.46frames/s]\nDetected: 0 | Progress:  80%|████████  | 404/504 [00:00<00:00, 496.85frames/s]\nDetected: 0 | Progress:  90%|█████████ | 454/504 [00:00<00:00, 490.08frames/s]\nDetected: 1 | Progress: 100%|██████████| 504/504 [00:01<00:00, 495.29frames/s]\n\n  0%|          | 0/503 [00:00<?, ?frame/s]ffmpeg version 6.0 Copyright (c) 2000-2023 the FFmpeg developers\n  built with Apple clang version 14.0.3 (clang-1403.0.22.14.1)\n  configuration: --prefix=/usr/local/Cellar/ffmpeg/6.0 --enable-shared --enable-pthreads --enable-version3 --cc=clang --host-cflags= --host-ldflags= --enable-ffplay --enable-gnutls --enable-gpl --enable-libaom --enable-libaribb24 --enable-libbluray --enable-libdav1d --enable-libmp3lame --enable-libopus --enable-librav1e --enable-librist --enable-librubberband --enable-libsnappy --enable-libsrt --enable-libsvtav1 --enable-libtesseract --enable-libtheora --enable-libvidstab --enable-libvmaf --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx264 --enable-libx265 --enable-libxml2 --enable-libxvid --enable-lzma --enable-libfontconfig --enable-libfreetype --enable-frei0r --enable-libass --enable-libopencore-amrnb --enable-libopencore-amrwb --enable-libopenjpeg --enable-libspeex --enable-libsoxr --enable-libzmq --enable-libzimg --disable-libjack --disable-indev=jack --enable-videotoolbox\n  libavutil      58.  2.100 / 58.  2.100\n  libavcodec     60.  3.100 / 60.  3.100\n  libavformat    60.  3.100 / 60.  3.100\n  libavdevice    60.  1.100 / 60.  1.100\n  libavfilter     9.  3.100 /  9.  3.100\n  libswscale      7.  1.100 /  7.  1.100\n  libswresample   4. 10.100 /  4. 10.100\n  libpostproc    57.  1.100 / 57.  1.100\nInput #0, yuv4mpegpipe, from '/Volumes/T7/deep_encode_dataset/DATASET_DEEP_ENCODE ...
